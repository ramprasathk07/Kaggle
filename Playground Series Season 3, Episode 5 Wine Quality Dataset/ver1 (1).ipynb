# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
train1=pd.read_csv('WineQT.csv')
train2=pd.read_csv('winered.csv')
train3=pd.read_csv('winequalityN.csv')
train3.drop(['type'],axis=1,inplace=True)
print(train.shape,test.shape)
# Out:
# (2056, 13) (1372, 12)

# %%
train.drop(['Id'],axis=1,inplace=True)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.0              0.50         0.39            2.20      0.073
# 1               9.3              0.30         0.73            2.30      0.092
# 2               7.1              0.51         0.03            2.10      0.059
# 3               8.1              0.87         0.22            2.60      0.084
# 4               8.5              0.36         0.30            2.30      0.079
# ...             ...               ...          ...             ...        ...
# 2051            6.6              0.31         0.13            2.00      0.056
# 2052            9.7              0.59         0.21            1.80      0.079
# 2053            7.7              0.43         0.42            1.70      0.071
# 2054            9.1              0.50         0.00            1.75      0.058
# 2055            6.2              0.31         0.18            2.30      0.059
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    30.0                  39.0  0.99572  3.33       0.77
# 1                    30.0                  67.0  0.99854  3.32       0.67
# 2                     3.0                  12.0  0.99660  3.52       0.73
# 3                    11.0                  65.0  0.99730  3.20       0.53
# 4                    10.0                  45.0  0.99444  3.20       1.36
# ...                   ...                   ...      ...   ...        ...
# 2051                 29.0                  42.0  0.99388  3.52       0.87
# 2052                 27.0                  65.0  0.99745  3.14       0.58
# 2053                 19.0                  37.0  0.99258  3.32       0.77
# 2054                  5.0                  13.0  0.99670  3.22       0.42
# 2055                 12.0                  28.0  0.99520  3.56       0.88
#
#       alcohol  quality
# 0        12.1        6
# 1        12.8        6
# 2        11.3        7
# 3         9.8        5
# 4         9.5        6
# ...       ...      ...
# 2051     12.0        7
# 2052      9.4        5
# 2053     12.5        8
# 2054      9.5        5
# 2055     11.4        7
#
# [2056 rows x 12 columns]

# %%
test
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     2056            7.2             0.510         0.01             2.0
# 1     2057            7.2             0.755         0.15             2.0
# 2     2058            8.4             0.460         0.40             2.0
# 3     2059            8.0             0.470         0.40             1.8
# 4     2060            6.5             0.340         0.32             2.1
# ...    ...            ...               ...          ...             ...
# 1367  3423            8.8             0.745         0.18             2.7
# 1368  3424           15.6             0.240         0.55             2.9
# 1369  3425            7.3             0.760         0.00             2.2
# 1370  3426            7.6             0.780         0.26             2.6
# 1371  3427            8.8             0.780         0.22             3.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.077                 31.0                  54.0  0.99748  3.39
# 1         0.102                 14.0                  35.0  0.99586  3.33
# 2         0.065                 21.0                  50.0  0.99774  3.08
# 3         0.056                 14.0                  25.0  0.99480  3.30
# 4         0.044                  8.0                  94.0  0.99356  3.23
# ...         ...                  ...                   ...      ...   ...
# 1367      0.084                 41.0                 115.0  0.99823  3.38
# 1368      0.062                 11.0                  25.0  0.99724  2.99
# 1369      0.095                  6.0                  19.0  0.99880  3.67
# 1370      0.118                 17.0                 104.0  0.99616  3.30
# 1371      0.085                 21.0                  43.0  0.99790  3.37
#
#       sulphates  alcohol
# 0          0.59      9.8
# 1          0.68     10.0
# 2          0.65      9.5
# 3          0.65     11.7
# 4          0.48     12.8
# ...         ...      ...
# 1367       0.70      9.8
# 1368       0.77     10.1
# 1369       0.60      9.4
# 1370       0.53      9.9
# 1371       0.56     10.2
#
# [1372 rows x 12 columns]

# %%
train1.drop(['Id'],axis=1,inplace=True)
train1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1138     11.0        6
# 1139      9.5        6
# 1140     10.5        5
# 1141     11.2        6
# 1142     10.2        5
#
# [1143 rows x 12 columns]

# %%
# train2.drop(['Id'],axis=1,inplace=True)
train2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
train=pd.concat([train,train1,train2,train3],axis=0)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.0             0.500         0.39             2.2      0.073
# 1               9.3             0.300         0.73             2.3      0.092
# 2               7.1             0.510         0.03             2.1      0.059
# 3               8.1             0.870         0.22             2.6      0.084
# 4               8.5             0.360         0.30             2.3      0.079
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    30.0                  39.0  0.99572  3.33       0.77
# 1                    30.0                  67.0  0.99854  3.32       0.67
# 2                     3.0                  12.0  0.99660  3.52       0.73
# 3                    11.0                  65.0  0.99730  3.20       0.53
# 4                    10.0                  45.0  0.99444  3.20       1.36
# ...                   ...                   ...      ...   ...        ...
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6493                 39.0                  51.0  0.99512  3.52        NaN
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0        12.1        6
# 1        12.8        6
# 2        11.3        7
# 3         9.8        5
# 4         9.5        6
# ...       ...      ...
# 6492     10.5        5
# 6493     11.2        6
# 6494     11.0        6
# 6495     10.2        5
# 6496     11.0        6
#
# [11295 rows x 12 columns]

# %%
train.dropna(inplace=True)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.0             0.500         0.39             2.2      0.073
# 1               9.3             0.300         0.73             2.3      0.092
# 2               7.1             0.510         0.03             2.1      0.059
# 3               8.1             0.870         0.22             2.6      0.084
# 4               8.5             0.360         0.30             2.3      0.079
# ...             ...               ...          ...             ...        ...
# 6491            6.8             0.620         0.08             1.9      0.068
# 6492            6.2             0.600         0.08             2.0      0.090
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    30.0                  39.0  0.99572  3.33       0.77
# 1                    30.0                  67.0  0.99854  3.32       0.67
# 2                     3.0                  12.0  0.99660  3.52       0.73
# 3                    11.0                  65.0  0.99730  3.20       0.53
# 4                    10.0                  45.0  0.99444  3.20       1.36
# ...                   ...                   ...      ...   ...        ...
# 6491                 28.0                  38.0  0.99651  3.42       0.82
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0        12.1        6
# 1        12.8        6
# 2        11.3        7
# 3         9.8        5
# 4         9.5        6
# ...       ...      ...
# 6491      9.5        6
# 6492     10.5        5
# 6494     11.0        6
# 6495     10.2        5
# 6496     11.0        6
#
# [11261 rows x 12 columns]

# %%
print(train.columns)
print()
print(test.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
#
# Index(['Id', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
train.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.0              0.50         0.39             2.2      0.073
# 1            9.3              0.30         0.73             2.3      0.092
# 2            7.1              0.51         0.03             2.1      0.059
# 3            8.1              0.87         0.22             2.6      0.084
# 4            8.5              0.36         0.30             2.3      0.079
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 30.0                  39.0  0.99572  3.33       0.77
# 1                 30.0                  67.0  0.99854  3.32       0.67
# 2                  3.0                  12.0  0.99660  3.52       0.73
# 3                 11.0                  65.0  0.99730  3.20       0.53
# 4                 10.0                  45.0  0.99444  3.20       1.36
#
#    alcohol  quality
# 0     12.1        6
# 1     12.8        6
# 2     11.3        7
# 3      9.8        5
# 4      9.5        6

# %%
# test=test.drop(['Id'],axis=1)

# %%
test.head()
# Out:
#      Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  2056            7.2             0.510         0.01             2.0
# 1  2057            7.2             0.755         0.15             2.0
# 2  2058            8.4             0.460         0.40             2.0
# 3  2059            8.0             0.470         0.40             1.8
# 4  2060            6.5             0.340         0.32             2.1
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.077                 31.0                  54.0  0.99748  3.39
# 1      0.102                 14.0                  35.0  0.99586  3.33
# 2      0.065                 21.0                  50.0  0.99774  3.08
# 3      0.056                 14.0                  25.0  0.99480  3.30
# 4      0.044                  8.0                  94.0  0.99356  3.23
#
#    sulphates  alcohol
# 0       0.59      9.8
# 1       0.68     10.0
# 2       0.65      9.5
# 3       0.65     11.7
# 4       0.48     12.8

# %%
train.quality.value_counts()
# Out:
# 6    4698
# 5    4131
# 7    1749
# 4     355
# 8     265
# 3      58
# 9       5
# Name: quality, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
train.quality.hist()
plt.show()

# %%
def add_features(df):
    # From https://www.kaggle.com/competitions/playground-series-s3e5/discussion/383685
    df['acidity_ratio'] = df['fixed acidity'] / df['volatile acidity']
    df['free_sulfur/total_sulfur'] = df['free sulfur dioxide'] / df['total sulfur dioxide']
    df['sugar/alcohol'] = df['residual sugar'] / df['alcohol']
    df['alcohol/density'] = df['alcohol'] / df['density']
    df['total_acid'] = df['fixed acidity'] + df['volatile acidity'] + df['citric acid']
    df['sulphates/chlorides'] = df['sulphates'] / df['chlorides']
    df['bound_sulfur'] = df['total sulfur dioxide'] - df['free sulfur dioxide']
    df['alcohol/pH'] = df['alcohol'] / df['pH']
    df['alcohol/acidity'] = df['alcohol'] / df['total_acid']
    df['alkalinity'] = df['pH'] + df['alcohol']
    df['mineral'] = df['chlorides'] + df['sulphates'] + df['residual sugar']
    df['density/pH'] = df['density'] / df['pH']
    df['total_alcohol'] = df['alcohol'] + df['residual sugar']
    
    # From https://www.kaggle.com/competitions/playground-series-s3e5/discussion/382698
    df['acid/density'] = df['total_acid']  / df['density']
    df['sulphate/density'] = df['sulphates']  / df['density']
    df['sulphates/acid'] = df['sulphates'] / df['volatile acidity']
    df['sulphates*alcohol'] = df['sulphates'] * df['alcohol']
    
    return df

# %%
# def h(df):
    
#     df.drop(['free sulfur dioxide','citric acid','fixed acidity','pH','residual sugar','chlorides','density','volatile acidity','total sulfur dioxide',],axis=1,inplace=True)
#     df.drop(['total_acid','mineral','sugar/alcohol','acid/density','alcohol/acidity','total_alcohol'],axis=1,inplace=True)
#     return df

# %%
train=add_features(train)
test=add_features(test)

# %%
# from sklearn.preprocessing import StandardScaler
# scaler=StandardScaler()
# def san(df):
#     for cols in df.columns:
#         df[cols]=scaler.fit_transform(df[cols].values.reshape(-1,1))

#     return df

# %%
# train=san(train)
# test=san(test)

# %%
n=train['quality'].unique()
n
# Out:
# array([6, 7, 5, 4, 8, 3, 9], dtype=int64)

# %%
n=len(n)
n
# Out:
# 7

# %%
# from sklearn.preprocessing import OneHotEncoder

# train=pd.get_dummies(train,columns=['quality'])

# %%
train.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'acidity_ratio',
#        'free_sulfur/total_sulfur', 'sugar/alcohol', 'alcohol/density',
#        'total_acid', 'sulphates/chlorides', 'bound_sulfur', 'alcohol/pH',
#        'alcohol/acidity', 'alkalinity', 'mineral', 'density/pH',
#        'total_alcohol', 'acid/density', 'sulphate/density', 'sulphates/acid',
#        'sulphates*alcohol'],
#       dtype='object')

# %%
x=train.drop(['quality'],axis=1)
y=train['quality']

# %%
x.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'acidity_ratio',
#        'free_sulfur/total_sulfur', 'sugar/alcohol', 'alcohol/density',
#        'total_acid', 'sulphates/chlorides', 'bound_sulfur', 'alcohol/pH',
#        'alcohol/acidity', 'alkalinity', 'mineral', 'density/pH',
#        'total_alcohol', 'acid/density', 'sulphate/density', 'sulphates/acid',
#        'sulphates*alcohol'],
#       dtype='object')

# %%
# from sklearn.preprocessing import FunctionTransformer

# fromer=FunctionTransformer(np.log1p,validate=True)
# x=fromer.fit_transform(x)
# test1=fromer.fit_transform(test)
# x=pd.DataFrame(x,columns=train.columns[1:])
# test=pd.DataFrame(test1,columns=test.columns[0:])
# x

# %%
test
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     2056            7.2             0.510         0.01             2.0
# 1     2057            7.2             0.755         0.15             2.0
# 2     2058            8.4             0.460         0.40             2.0
# 3     2059            8.0             0.470         0.40             1.8
# 4     2060            6.5             0.340         0.32             2.1
# ...    ...            ...               ...          ...             ...
# 1367  3423            8.8             0.745         0.18             2.7
# 1368  3424           15.6             0.240         0.55             2.9
# 1369  3425            7.3             0.760         0.00             2.2
# 1370  3426            7.6             0.780         0.26             2.6
# 1371  3427            8.8             0.780         0.22             3.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.077                 31.0                  54.0  0.99748  3.39
# 1         0.102                 14.0                  35.0  0.99586  3.33
# 2         0.065                 21.0                  50.0  0.99774  3.08
# 3         0.056                 14.0                  25.0  0.99480  3.30
# 4         0.044                  8.0                  94.0  0.99356  3.23
# ...         ...                  ...                   ...      ...   ...
# 1367      0.084                 41.0                 115.0  0.99823  3.38
# 1368      0.062                 11.0                  25.0  0.99724  2.99
# 1369      0.095                  6.0                  19.0  0.99880  3.67
# 1370      0.118                 17.0                 104.0  0.99616  3.30
# 1371      0.085                 21.0                  43.0  0.99790  3.37
#
#       ...  alcohol/pH  alcohol/acidity  alkalinity  mineral  density/pH  \
# 0     ...    2.890855         1.269430       13.19    2.667    0.294242
# 1     ...    3.003003         1.233806       13.33    2.782    0.299057
# 2     ...    3.084416         1.025918       12.58    2.715    0.323942
# 3     ...    3.545455         1.319053       15.00    2.506    0.301455
# 4     ...    3.962848         1.787709       16.03    2.624    0.307604
# ...   ...         ...              ...         ...      ...         ...
# 1367  ...    2.899408         1.007712       13.18    3.484    0.295334
# 1368  ...    3.377926         0.616229       13.09    3.732    0.333525
# 1369  ...    2.561308         1.166253       13.07    2.895    0.272153
# 1370  ...    3.000000         1.145833       13.20    3.248    0.301867
# 1371  ...    3.026706         1.040816       13.57    3.645    0.296113
#
#       total_alcohol  acid/density  sulphate/density  sulphates/acid  \
# 0              11.8      7.739504          0.591491        1.156863
# 1              12.0      8.138694          0.682827        0.900662
# 2              11.5      9.280975          0.651472        1.413043
# 3              13.5      8.916365          0.653398        1.382979
# 4              14.9      7.206409          0.483111        1.411765
# ...             ...           ...               ...             ...
# 1367           12.5      9.742244          0.701241        0.939597
# 1368           13.0     16.435362          0.772131        3.208333
# 1369           11.6      8.069684          0.600721        0.789474
# 1370           12.5      8.673305          0.532043        0.679487
# 1371           13.2      9.820623          0.561178        0.717949
#
#       sulphates*alcohol
# 0                 5.782
# 1                 6.800
# 2                 6.175
# 3                 7.605
# 4                 6.144
# ...                 ...
# 1367              6.860
# 1368              7.777
# 1369              5.640
# 1370              5.247
# 1371              5.712
#
# [1372 rows x 29 columns]

# %%
from sklearn.feature_selection import SelectKBest, chi2,f_classif

# your data X and target y

# create the selector
selector = SelectKBest(f_classif, k=15)

# fit the selector to your data
selector.fit(x, y)

# get the selected features
selected_features = selector.transform(x)
sel=selector.get_support()
x=x.loc[:,sel]
x
# Out:
#       volatile acidity  citric acid  chlorides  density  alcohol  \
# 0                0.500         0.39      0.073  0.99572     12.1
# 1                0.300         0.73      0.092  0.99854     12.8
# 2                0.510         0.03      0.059  0.99660     11.3
# 3                0.870         0.22      0.084  0.99730      9.8
# 4                0.360         0.30      0.079  0.99444      9.5
# ...                ...          ...        ...      ...      ...
# 6491             0.620         0.08      0.068  0.99651      9.5
# 6492             0.600         0.08      0.090  0.99490     10.5
# 6494             0.510         0.13      0.076  0.99574     11.0
# 6495             0.645         0.12      0.075  0.99547     10.2
# 6496             0.310         0.47      0.067  0.99549     11.0
#
#       acidity_ratio  free_sulfur/total_sulfur  alcohol/density  \
# 0         16.000000                  0.769231        12.152011
# 1         31.000000                  0.447761        12.818715
# 2         13.921569                  0.250000        11.338551
# 3          9.310345                  0.169231         9.826532
# 4         23.611111                  0.222222         9.553115
# ...             ...                       ...              ...
# 6491      10.967742                  0.736842         9.533271
# 6492      10.333333                  0.727273        10.553825
# 6494      12.352941                  0.725000        11.047060
# 6495       9.147287                  0.727273        10.246416
# 6496      19.354839                  0.428571        11.049835
#
#       sulphates/chlorides  alcohol/pH  alcohol/acidity  alkalinity  \
# 0               10.547945    3.633634         1.361080       15.43
# 1                7.282609    3.855422         1.239109       16.12
# 2               12.372881    3.210227         1.479058       14.82
# 3                6.309524    3.062500         1.066376       13.00
# 4               17.215190    2.968750         1.037118       12.70
# ...                   ...         ...              ...         ...
# 6491            12.058824    2.777778         1.266667       12.92
# 6492             6.444444    3.043478         1.526163       13.95
# 6494             9.868421    3.216374         1.585014       14.42
# 6495             9.466667    2.857143         1.530383       13.77
# 6496             9.850746    3.244838         1.622419       14.39
#
#       total_alcohol  sulphates/acid  sulphates*alcohol
# 0              14.3        1.540000              9.317
# 1              15.1        2.233333              8.576
# 2              13.4        1.431373              8.249
# 3              12.4        0.609195              5.194
# 4              11.8        3.777778             12.920
# ...             ...             ...                ...
# 6491           11.4        1.322581              7.790
# 6492           12.5        0.966667              6.090
# 6494           13.3        1.470588              8.250
# 6495           12.2        1.100775              7.242
# 6496           14.6        2.129032              7.260
#
# [11261 rows x 15 columns]

# %%
# x=x.drop(['quality'],axis=1)

# %%
sel=x.columns

# %%
test.columns
# Out:
# Index(['Id', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'acidity_ratio', 'free_sulfur/total_sulfur', 'sugar/alcohol',
#        'alcohol/density', 'total_acid', 'sulphates/chlorides', 'bound_sulfur',
#        'alcohol/pH', 'alcohol/acidity', 'alkalinity', 'mineral', 'density/pH',
#        'total_alcohol', 'acid/density', 'sulphate/density', 'sulphates/acid',
#        'sulphates*alcohol'],
#       dtype='object')

# %%
# test.drop(['Id'],axis=1,inplace=True)
test=test.loc[:,sel]
test
# Out:
#       volatile acidity  citric acid  chlorides  density  alcohol  \
# 0                0.510         0.01      0.077  0.99748      9.8
# 1                0.755         0.15      0.102  0.99586     10.0
# 2                0.460         0.40      0.065  0.99774      9.5
# 3                0.470         0.40      0.056  0.99480     11.7
# 4                0.340         0.32      0.044  0.99356     12.8
# ...                ...          ...        ...      ...      ...
# 1367             0.745         0.18      0.084  0.99823      9.8
# 1368             0.240         0.55      0.062  0.99724     10.1
# 1369             0.760         0.00      0.095  0.99880      9.4
# 1370             0.780         0.26      0.118  0.99616      9.9
# 1371             0.780         0.22      0.085  0.99790     10.2
#
#       acidity_ratio  free_sulfur/total_sulfur  alcohol/density  \
# 0         14.117647                  0.574074         9.824758
# 1          9.536424                  0.400000        10.041572
# 2         18.260870                  0.420000         9.521519
# 3         17.021277                  0.560000        11.761158
# 4         19.117647                  0.085106        12.882966
# ...             ...                       ...              ...
# 1367      11.812081                  0.356522         9.817377
# 1368      65.000000                  0.440000        10.127953
# 1369       9.605263                  0.315789         9.411294
# 1370       9.743590                  0.163462         9.938163
# 1371      11.282051                  0.488372        10.221465
#
#       sulphates/chlorides  alcohol/pH  alcohol/acidity  alkalinity  \
# 0                7.662338    2.890855         1.269430       13.19
# 1                6.666667    3.003003         1.233806       13.33
# 2               10.000000    3.084416         1.025918       12.58
# 3               11.607143    3.545455         1.319053       15.00
# 4               10.909091    3.962848         1.787709       16.03
# ...                   ...         ...              ...         ...
# 1367             8.333333    2.899408         1.007712       13.18
# 1368            12.419355    3.377926         0.616229       13.09
# 1369             6.315789    2.561308         1.166253       13.07
# 1370             4.491525    3.000000         1.145833       13.20
# 1371             6.588235    3.026706         1.040816       13.57
#
#       total_alcohol  sulphates/acid  sulphates*alcohol
# 0              11.8        1.156863              5.782
# 1              12.0        0.900662              6.800
# 2              11.5        1.413043              6.175
# 3              13.5        1.382979              7.605
# 4              14.9        1.411765              6.144
# ...             ...             ...                ...
# 1367           12.5        0.939597              6.860
# 1368           13.0        3.208333              7.777
# 1369           11.6        0.789474              5.640
# 1370           12.5        0.679487              5.247
# 1371           13.2        0.717949              5.712
#
# [1372 rows x 15 columns]

# %%
y
# Out:
# 0       6
# 1       6
# 2       7
# 3       5
# 4       6
#        ..
# 6491    6
# 6492    5
# 6494    6
# 6495    5
# 6496    6
# Name: quality, Length: 11261, dtype: int64

# %%
# y=y.astype('int')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# array([3, 3, 4, ..., 3, 2, 3], dtype=int64)

# %%
# import numpy as np
# import pandas as pd
# from imblearn.over_sampling import SMOTE

# # Use SMOTE to oversample the minority classes
# smote = SMOTE(sampling_strategy='auto', k_neighbors=10, random_state=0)
# X_resampled, y_resampled = smote.fit_resample(x, y)

# %%
# y=y.astype('int')

# %%
# import lightgbm as lgb
# import optuna
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# load the breast cancer dataset
X_train,  X_val, y_train,  y_val= train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#import lightgbm as lgb
import lightgbm as lgb



clf=lgb.LGBMClassifier()
clf.fit(X_train,y_train)
y_pred=clf.predict(X_val)
from sklearn.metrics import accuracy_score
accuracy_score(y_val,y_pred)
# Out:
# 0.738126941855304

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
clf.fit(X_train,y_train)
y_pred=clf.predict(X_val)
from sklearn.metrics import accuracy_score
accuracy_score(y_val,y_pred)
# Out:
# 0.7678650687971593

# %%
# from catboost import CatBoostClassifier
# clf=CatBoostClassifier()
# clf.fit(X_train,y_train)
# y_pred=clf.predict(X_val)
# from sklearn.metrics import accuracy_score
# accuracy_score(y_val,y_pred)

# %%
# clf=lgb.LGBMClassifier(**r)
# clf.fit(x,y)

# %%
ypred=clf.predict(test)
ypred = ypred.reshape(-1, 1)
ypred = le.inverse_transform(ypred)
# Out:
# c:\Users\xfini\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
ypred
# Out:
# array([5, 5, 5, ..., 5, 5, 5], dtype=int64)

# %%
c=pd.read_csv('sample_submission.csv')
c.head()
# Out:
#      Id  quality
# 0  2056        5
# 1  2057        5
# 2  2058        5
# 3  2059        5
# 4  2060        5

# %%
c['quality']=ypred

# %%
c
# Out:
#         Id  quality
# 0     2056        5
# 1     2057        5
# 2     2058        5
# 3     2059        6
# 4     2060        6
# ...    ...      ...
# 1367  3423        5
# 1368  3424        6
# 1369  3425        5
# 1370  3426        5
# 1371  3427        5
#
# [1372 rows x 2 columns]

# %%
c.to_csv('lopt.csv',index=False)
